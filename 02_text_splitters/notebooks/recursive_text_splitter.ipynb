# %% [markdown]
# ### Demo Text

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text = """Hi how are you
My name is Rahul

I am teaching RAG
We are Learning about RAG"""

print(text)
# Out:
# Hi how are you
# My name is Rahul
#
# I am teaching RAG
# We are Learning about RAG

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=10,
    chunk_overlap=0
)

# %%
splitter.split_text(text)
# Out:
# ['Hi how are',
#  'you',
#  'My name',
#  'is Rahul',
#  'I am',
#  'teaching',
#  'RAG',
#  'We are',
#  'Learning',
#  'about RAG']

# %% [markdown]
# ### Code

# %%
example_text = """Artificial intelligence is transforming technology and shaping the future.

Machine learning algorithms are becoming more sophisticated every day. 
Deep learning models can now process vast amounts of data efficiently.

Natural language processing has made significant strides in recent years.
Transformers architecture revolutionized the field in 2017.
Models like GPT and BERT have set new benchmarks.

Computer vision systems can now identify objects with remarkable accuracy.
Convolutional neural networks excel at image recognition tasks.
Self-driving cars rely heavily on advanced computer vision.

The impact of AI extends across multiple industries including healthcare, finance, and transportation.
Ethical considerations around AI development are becoming increasingly important.
Researchers are working on making AI systems more transparent and explainable."""

# %%
# create the splitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=150,
    chunk_overlap=20,
    separators=[" ", ""]
)

# %%
# split the text

chunks = splitter.split_text(example_text)

print(chunks)
# Out:
# ['Artificial intelligence is transforming technology and shaping the future.\n\nMachine learning algorithms are becoming more sophisticated every day.', 'every day. \nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in', 'strides in recent years.\nTransformers architecture revolutionized the field in 2017.\nModels like GPT and BERT have set new benchmarks.\n\nComputer', 'vision systems can now identify objects with remarkable accuracy.\nConvolutional neural networks excel at image recognition tasks.\nSelf-driving cars', 'cars rely heavily on advanced computer vision.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and', 'finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI', 'on making AI systems more transparent and explainable.']

# %%
from termcolor import COLORS, colored
from random import choice

# %%
def display_chunks(chunks):
    colors_list = list(COLORS.keys())[2:8]
    print(f"Total Number of Chunks: {len(chunks)}")
    for num, chunk in enumerate(chunks, 1):
        print(f"Chunk {num}: Length {len(chunk)} chars")
        print(colored(text=chunk, color=choice(colors_list)), end="\n\n")

# %%
display_chunks(chunks)
# Out:
# Total Number of Chunks: 7
# Chunk 1: Length 146 chars
# Artificial intelligence is transforming technology and shaping the future.
#
# Machine learning algorithms are becoming more sophisticated every day.
#
# Chunk 2: Length 143 chars
# every day.
# Deep learning models can now process vast amounts of data efficiently.
#
# Natural language processing has made significant strides in
#
# Chunk 3: Length 144 chars
# strides in recent years.
# Transformers architecture revolutionized the field in 2017.
# Models like GPT and BERT have set new benchmarks.
#
# Computer
#
# Chunk 4: Length 147 chars
# vision systems can now identify objects with remarkable accuracy.
# Convolutional neural networks excel at image recognition tasks.
# Self-driving cars
#
# Chunk 5: Length 134 chars
# cars rely heavily on advanced computer vision.
#
# The impact of AI extends across multiple industries including healthcare, finance, and
#
# Chunk 6: Length 147 chars
# finance, and transportation.
# Ethical considerations around AI development are becoming increasingly important.
# Researchers are working on making AI
#
# Chunk 7: Length 54 chars
# on making AI systems more transparent and explainable.

# %% [markdown]
# ### Documents

# %%
from langchain_core.documents import Document

# %%
# create the list of documents

list_of_text = [text, example_text]

docs = [Document(page_content=text) for text in list_of_text]

print(docs)
# Out:
# [Document(metadata={}, page_content='Hi how are you\nMy name is Rahul\n\nI am teaching RAG\nWe are Learning about RAG'), Document(metadata={}, page_content='Artificial intelligence is transforming technology and shaping the future.\n\nMachine learning algorithms are becoming more sophisticated every day. \nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in recent years.\nTransformers architecture revolutionized the field in 2017.\nModels like GPT and BERT have set new benchmarks.\n\nComputer vision systems can now identify objects with remarkable accuracy.\nConvolutional neural networks excel at image recognition tasks.\nSelf-driving cars rely heavily on advanced computer vision.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI systems more transparent and explainable.')]

# %%
# split the documents

chunks_docs = splitter.split_documents(docs)

print(chunks_docs)
print(len(chunks_docs))
# Out:
# [Document(metadata={}, page_content='Hi how are you\nMy name is Rahul\n\nI am teaching RAG\nWe are Learning about RAG'), Document(metadata={}, page_content='Artificial intelligence is transforming technology and shaping the future.\n\nMachine learning algorithms are becoming more sophisticated every day.'), Document(metadata={}, page_content='every day. \nDeep learning models can now process vast amounts of data efficiently.\n\nNatural language processing has made significant strides in'), Document(metadata={}, page_content='strides in recent years.\nTransformers architecture revolutionized the field in 2017.\nModels like GPT and BERT have set new benchmarks.\n\nComputer'), Document(metadata={}, page_content='vision systems can now identify objects with remarkable accuracy.\nConvolutional neural networks excel at image recognition tasks.\nSelf-driving cars'), Document(metadata={}, page_content='cars rely heavily on advanced computer vision.\n\nThe impact of AI extends across multiple industries including healthcare, finance, and'), Document(metadata={}, page_content='finance, and transportation.\nEthical considerations around AI development are becoming increasingly important.\nResearchers are working on making AI'), Document(metadata={}, page_content='on making AI systems more transparent and explainable.')]
# 8
