# %%
from langchain_community.document_loaders import WebBaseLoader
from pprint import pp
# Out:
# C:\Users\Uttam\AppData\Local\Temp\ipykernel_1264\4086227143.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# create the loader

url_1 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader"
url_2 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer"
url_3 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber"

loader = WebBaseLoader(web_paths=[url_1, url_2, url_3])

# %%
# load the document

documents = loader.load()

# %%
len(documents)
# Out:
# 3

# %%
print(documents[2].page_content)

# %%
pp(documents[2].metadata)
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber',
#  'language': 'No language found.'}

# %% [markdown]
# ### Recursive Loader

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

# %%
# create the loader

base_url = "https://docs.langchain.com/oss/python/integrations/document_loaders"

loader = RecursiveUrlLoader(url=base_url,
                            max_depth=2)

# %%
# load the documents

documents = loader.load()
# Out:
# e:\Projects\Campusx-Advance-Rag\Code\.venv\Lib\site-packages\langchain_community\document_loaders\recursive_url_loader.py:44: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")

# %%
# number of documents

len(documents)
# Out:
# 79

# %%
documents[0].page_content[:500]
# Out:
# '<!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify-assets/_next/static/media/83afe278b6a6bb3c.p.3a6ba036.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="'

# %%
documents[0].metadata
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loader integrations - Docs by LangChain',
#  'description': 'Integrate with document loaders using LangChain Python.',
#  'language': 'en'}

# %%
# lazy load

documents_lazy_load = loader.lazy_load()

# %%
documents_lazy_load
# Out:
# <generator object RecursiveUrlLoader._get_child_links_recursive at 0x0000014E498474C0>

# %%
counter = 0

for document in documents_lazy_load:
    # stop condition
    if counter == 20:
        break
    
    # incerement the counter
    counter += 1
    
    # print metadata and page content
    print(document.page_content[0:300])
    pp(document.metadata)
# Out:
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loader integrations - Docs by LangChain',
#  'description': 'Integrate with document loaders using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/upstage',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Upstage integration - Docs by LangChain',
#  'description': 'Integrate with the Upstage document loader using LangChain '
#                 'Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/index',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loader integrations - Docs by LangChain',
#  'description': 'Integrate with document loaders using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google cloud storage directory integration - Docs by LangChain',
#  'description': 'Integrate with the Google cloud storage directory document '
#                 'loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/tools',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Tool integrations - Docs by LangChain',
#  'description': 'Integrate with tools using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_bigquery',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google bigquery integration - Docs by LangChain',
#  'description': 'Integrate with the Google bigquery document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/memory/mongodb-long-term-memory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Long-term memory with MongoDB Atlas - Docs by LangChain',
#  'description': 'Persist agent long-term memory with MongoDBStore and MongoDB '
#                 'Atlas.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_bigtable',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google bigtable integration - Docs by LangChain',
#  'description': 'Integrate with the Google bigtable document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_firestore',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google firestore (native mode) integration - Docs by LangChain',
#  'description': 'Integrate with the Google firestore (native mode) document '
#                 'loader using LangChain Python.',
#  'language': 'en'}
# @font-face{font-family:paperMono;src:url(../media/PaperMono_Variable.p.aa32f7a0.woff2)format("woff2");font-display:swap;font-weight:100 800}.papermono_89c757f2-module__6aS5zq__className{font-family:paperMono,ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace}.pap
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/462bacc63bed9960.css?dpl=dpl_WUrXqCd5nPFDSzoTYvx4Wt8NzcVY',
#  'content_type': 'text/css; charset=utf-8'}
# (globalThis.TURBOPACK||(globalThis.TURBOPACK=[])).push(["object"==typeof document?document.currentScript:void 0,818800,(e,t,r)=>{"use strict";var n=e.r(271645);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var r=2;r<argume
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/7d632cf627c34201.js?dpl=dpl_WUrXqCd5nPFDSzoTYvx4Wt8NzcVY',
#  'content_type': 'application/javascript; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_alloydb',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google alloydb for postgresql integration - Docs by LangChain',
#  'description': 'Integrate with the Google alloydb for postgresql document '
#                 'loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_speech_to_text',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google speech-to-text audio transcripts integration - Docs by '
#           'LangChain',
#  'description': 'Integrate with the Google speech-to-text audio transcripts '
#                 'document loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/oracleadb_loader',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Oracle autonomous database integration - Docs by LangChain',
#  'description': 'Integrate with the Oracle autonomous database document loader '
#                 'using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/nvidia',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'NVIDIA - Docs by LangChain',
#  'description': 'Integrate with NVIDIA using LangChain Python.',
#  'language': 'en'}
# @layer properties{@supports (((-webkit-hyphens:none)) and (not (margin-trim:inline))) or ((-moz-orient:inline) and (not (color:rgb(from red r g b)))){*,:before,:after,::backdrop{--tw-translate-x:0;--tw-translate-y:0;--tw-translate-z:0;--tw-scale-x:1;--tw-scale-y:1;--tw-scale-z:1;--tw-rotate-x:initia
# {'source': 'https://docs.langchain.com/mintlify-assets/_next/static/chunks/8ec82115c8ae24bd.css?dpl=dpl_WUrXqCd5nPFDSzoTYvx4Wt8NzcVY',
#  'content_type': 'text/css; charset=utf-8'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/ollama',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Ollama integrations - Docs by LangChain',
#  'description': 'Integrate with Ollama using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/anthropic',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Anthropic (Claude) integrations - Docs by LangChain',
#  'description': 'Integrate with Anthropic (Claude) using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_datastore',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google firestore in datastore mode integration - Docs by LangChain',
#  'description': 'Integrate with the Google firestore in datastore mode '
#                 'document loader using LangChain Python.',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="inter_1d81deff-module__CYM0aG__variable papermono_89c757f2-module__6aS5zq__variable dark" data-banner-state="visible" data-assistant-state="closed" data-page-mode="none" data-current-path="/"><head><meta charSet="utf-8"/><meta name="viewport" content="width=devi
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/unstructured_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Unstructured integration - Docs by LangChain',
#  'description': 'Integrate with the Unstructured document loader using '
#                 'LangChain Python.',
#  'language': 'en'}
